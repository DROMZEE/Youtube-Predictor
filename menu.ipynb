# %% [markdown]
# # P2 : Projet Youtube Predictor
#
# ## Le projet
#
# Ce deuxième projet (P2) est donnée dans le cadre de la formation "Développeur.se Data IA" de l'école Simplon de Biarritz
#
# ### Objectifs
#
# * Trouver et importer un jeu de données
# * Analyser et traiter les données
# * Réaliser des graphiques pertinent
# * Créer une présentation reposant sur un dasboard et un support papier
#
#
# * Le sujet complet est diponible ici : [Sujet P2](P2_sujet.ipynb)
#
# ### L'équipe
#
# Binôme :
# * Fred Fred
# * Cédric Dromzée
#
#
# ## Les données
#
# ### Le dataset Youtube de Kaggle
#
# Nous avons sélectionné un dataset sur Youtube disponible sur le site Kaggle
# * https://www.kaggle.com/datasnaek/youtube-new/
#
# ### Centralisation des données
#
# Nous avons décidé de centraliser les données dans un seul DataFrame
#
# * [fusion](./fusion/fusion.ipynb)
#
# ### L'API
#
# Au cours de notre analyse nous avons souhaité analyser l'impact de la durée des vidéos.
# Nous sommes passé par l'API via le service Google Console ...
# Il est nécessaire de configurer une clé
# Nous avons utilisé une librairie :
#
# pour chaque requete le nombre d'id de vidéo est limité.
#
# * [l'API](./api/api2.ipynb)
#
# ## Visualisation
#
# * [Analyse_textuelle](./words/Analyse_textuelle.ipynb)
# * [les catégories](./visu/cat.ipynb)
#
# ## Livrables
#
# * [le rapport](rapport.ipynb)
# * le dashboard
#
#
# ## Built With
#
# * Python - Programming language
# * Jupyter - Jupyter Notebook
# * matplotlib - Python 2D plotting library
# * Seaborn
# * gitignore - Create useful .gitignore files for your project
# * Visual studio Code
