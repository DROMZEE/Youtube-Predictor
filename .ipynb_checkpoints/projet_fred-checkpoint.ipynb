# %% [markdown]
# # Projet 2 - Youtube --Fred--

# %% [markdown]
# ### Import des modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import des données

# %% [markdown]
# ##### Data

# %%
data_fr = pd.read_csv("data/FRvideos.csv")
data_us = pd.read_csv("data/USvideos.csv")

# %%
print(data_us.shape)
data_us.head(2)
# Out:
# (40949, 16)
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
#
#                                                title    channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE     CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...  LastWeekTonight
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
#
#                                                 tags    views  likes  \
# 0                                    SHANtell martin   748374  57527
# 1  last week tonight trump presidency|"last week ...  2418783  97185
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...

# %%
print(data_fr.shape)
data_fr.head(2)
# Out:
# (40724, 16)
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
#
#                                                 tags   views  likes  dislikes  \
# 0  Raptor"|"Dissident"|"Expliquez"|"moi"|"cette"|...  212702  29282      1108
# 1                                             [none]  432721  14053       576
#
#    comment_count                                  thumbnail_link  \
# 0           3817  https://i.ytimg.com/vi/Ro6eob0LrCY/default.jpg
# 1           1161  https://i.ytimg.com/vi/Yo84eqYwP98/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
#
#                                          description
# 0  Dimanche.\n18h30.\nSoyez présents pour la vidé...
# 1  Le jeu de société: https://goo.gl/hhG1Ta\n\nGa...

# %%
data_fr[data_fr["category_id"] == 26]
# Out:
#           video_id trending_date  \
# 16     RpEJCznFreQ      17.14.11
# 25     avNyRo2Vd9U      17.14.11
# 76     ko1ebVo3C70      17.14.11
# 92     1SiKopOt-QM      17.14.11
# 119    BaPXooxJp00      17.14.11
# ...            ...           ...
# 40544  FYdIZP_o77s      18.14.06
# 40552  PStvIRCJWU4      18.14.06
# 40610  JTrOlNOp0iA      18.14.06
# 40662  VU5CEdBAYPA      18.14.06
# 40681  AIyy55-WBkc      18.14.06
#
#                                                    title  \
# 16                 FAIRE UNE GLACE ROULÉE (sans machine)
# 25     10 RECETTES DIY DE BAUME À LÈVRES À PARTIR DE ...
# 76     20 ASTUCES DE GENIE POUR L'ECOLE QUE VOUS AURI...
# 92      26 SIMPLE WAYS TO SPEED UP YOUR EVERYDAY ROUTINE
# 119              Je réinspire ma vie - GEORGIA HORACKOVA
# ...                                                  ...
# 40544        ♡• SÉLÉCTIONNÉE POUR LA COUPE DU MONDE ? •♡
# 40552              30 ASTUCES QUE LES FILLES VONT ADORER
# 40610               Club sandwich poulet bacon - Youcook
# 40662  بدأ العد العكسي😱زينت بيتي بديكورات لإستقبال ال...
# 40681         حلويات العيد بمكونات إقتصادية وبكمية كتيرة
#
#                  channel_title  category_id              publish_time  \
# 16            Alexandre Calvez           26  2017-11-12T18:00:02.000Z
# 25              Troom Troom FR           26  2017-11-13T13:00:01.000Z
# 76            Le Saviez-Vous ?           26  2017-11-13T16:27:46.000Z
# 92             5-Minute Crafts           26  2017-11-13T16:30:00.000Z
# 119          Georgia Horackova           26  2017-11-12T18:25:11.000Z
# ...                        ...          ...                       ...
# 40544      L'atelier de Roxane           26  2018-06-13T10:00:02.000Z
# 40552              BRICO SYMPA           26  2018-06-13T10:35:13.000Z
# 40610          YouCook Cuisine           26  2018-06-12T15:30:01.000Z
# 40662  Malak World - عالم ملاك           26  2018-06-13T14:38:35.000Z
# 40681             Asmaa Beauty           26  2018-06-13T18:42:43.000Z
#
#                                                     tags   views  likes  \
# 16     Alexandre Calvez"|"Crash Test"|"Alexandre"|"Ca...  373013  23645
# 25     DIY"|"baume à lèvres maison"|"EOS"|"gommage"|"...  240158   6765
# 76     DIY"|"faites le vous même"|"la guerre des blag...   24072   2127
# 92     5-Minute Crafts"|"DIY"|"Do it yourself"|"craft...  803400  15547
# 119    georgia horackova"|"inspiration"|"challenge"|"...  102674  11082
# ...                                                  ...     ...    ...
# 40544  recette foot|"recette football"|"coupe du mond...  252034  22074
# 40552  Brico Sympa|"Fait-Maison"|"Fait-main"|"Bricola...   29933    626
# 40610  youcook|"cuisine"|"recette"|"video youcook"|"c...   63468   4326
# 40662  حلويات سهلة|"حلويات سهلة وسريعة"|"حلويات بدون ...   37211   2569
# 40681  Asmaa|"Asmaa beauty"|"Maroc"|"Beauty"|"Ramadan...  125023   9142
#
#        dislikes  comment_count  \
# 16          411            813
# 25          160            935
# 76          158            306
# 92         1130            955
# 119         256            681
# ...         ...            ...
# 40544       356           2125
# 40552        57             77
# 40610        49            235
# 40662        71            237
# 40681       213           1642
#
#                                        thumbnail_link  comments_disabled  \
# 16     https://i.ytimg.com/vi/RpEJCznFreQ/default.jpg              False
# 25     https://i.ytimg.com/vi/avNyRo2Vd9U/default.jpg              False
# 76     https://i.ytimg.com/vi/ko1ebVo3C70/default.jpg              False
# 92     https://i.ytimg.com/vi/1SiKopOt-QM/default.jpg              False
# 119    https://i.ytimg.com/vi/BaPXooxJp00/default.jpg              False
# ...                                               ...                ...
# 40544  https://i.ytimg.com/vi/FYdIZP_o77s/default.jpg              False
# 40552  https://i.ytimg.com/vi/PStvIRCJWU4/default.jpg              False
# 40610  https://i.ytimg.com/vi/JTrOlNOp0iA/default.jpg              False
# 40662  https://i.ytimg.com/vi/VU5CEdBAYPA/default.jpg              False
# 40681  https://i.ytimg.com/vi/AIyy55-WBkc/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 16                False                   False
# 25                False                   False
# 76                False                   False
# 92                False                   False
# 119               False                   False
# ...                 ...                     ...
# 40544             False                   False
# 40552             False                   False
# 40610             False                   False
# 40662             False                   False
# 40681             False                   False
#
#                                              description
# 16     👉 Ma page facebook : https://facebook.com/alex...
# 25     Abonnez-vous ici : http://bit.ly/2vnYmfc\n12 B...
# 76     20 ASTUCES DE GENIE POUR L'ECOLE QUE VOUS AURI...
# 92     Subscribe to 5-Minute Crafts KIDS: https://goo...
# 119    ---------------------------------👇-- DÉROULE M...
# ...                                                  ...
# 40544  •♡• Pour cette semaine spéciale coupe du monde...
# 40552  Apprends à réaliser des masques pour le visage...
# 40610  Ingrédients :- Pain de mie, poulet, bacon, avo...
# 40662  بدأ العد العكسي😱زينت بيتي بديكورات لإستقبال ال...
# 40681  تابعوني أيضا على الشبكات الاجتماعية:       * F...
#
# [2361 rows x 16 columns]

# %% [markdown]
# ##### Catégories

# %%
cat_fr = pd.read_json("data/FR_category_id.json")
cat_us = pd.read_json("data/US_category_id.json")

# %% [markdown]
# ##### Mise en listes

# %%
dic_cat_fr = {}
for x in range(cat_fr.shape[0]):
    ident = cat_fr.iloc[x,2]["id"]
    title = cat_fr.iloc[x,2]["snippet"]["title"]
    dic_cat_fr[ident] = title
print(dic_cat_fr)
# Out:
# {'1': 'Film & Animation', '2': 'Autos & Vehicles', '10': 'Music', '15': 'Pets & Animals', '17': 'Sports', '18': 'Short Movies', '19': 'Travel & Events', '20': 'Gaming', '21': 'Videoblogging', '22': 'People & Blogs', '23': 'Comedy', '24': 'Entertainment', '25': 'News & Politics', '26': 'Howto & Style', '27': 'Education', '28': 'Science & Technology', '30': 'Movies', '31': 'Anime/Animation', '32': 'Action/Adventure', '33': 'Classics', '34': 'Comedy', '35': 'Documentary', '36': 'Drama', '37': 'Family', '38': 'Foreign', '39': 'Horror', '40': 'Sci-Fi/Fantasy', '41': 'Thriller', '42': 'Shorts', '43': 'Shows', '44': 'Trailers'}

# %%
dic_cat_us = {}
for x in range(cat_us.shape[0]):
    ident = cat_us.iloc[x,2]["id"]
    title = cat_us.iloc[x,2]["snippet"]["title"]
    dic_cat_us[ident] = title
print(dic_cat_us)
# Out:
# {'1': 'Film & Animation', '2': 'Autos & Vehicles', '10': 'Music', '15': 'Pets & Animals', '17': 'Sports', '18': 'Short Movies', '19': 'Travel & Events', '20': 'Gaming', '21': 'Videoblogging', '22': 'People & Blogs', '23': 'Comedy', '24': 'Entertainment', '25': 'News & Politics', '26': 'Howto & Style', '27': 'Education', '28': 'Science & Technology', '29': 'Nonprofits & Activism', '30': 'Movies', '31': 'Anime/Animation', '32': 'Action/Adventure', '33': 'Classics', '34': 'Comedy', '35': 'Documentary', '36': 'Drama', '37': 'Family', '38': 'Foreign', '39': 'Horror', '40': 'Sci-Fi/Fantasy', '41': 'Thriller', '42': 'Shorts', '43': 'Shows', '44': 'Trailers'}

# %% [markdown]
# ### Modifications des data sets

# %% [markdown]
# ##### Modification d'index

# %%
data_fr = data_fr.set_index("video_id")
data_us = data_us.set_index("video_id")

# %% [markdown]
# ##### Ajout d'une colonne "category"

# %%
data_fr["category"] = ""
for x, y in dic_cat_fr.items():
    filtre = data_fr["category_id"] == int(x)
    data_fr["category"][filtre] = y
data_fr
# Out:
# /home/fred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#             trending_date                                              title  \
# video_id
# Ro6eob0LrCY      17.14.11           Malika LePen : Femme de Gauche - Trailer
# Yo84eqYwP98      17.14.11  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...
# ceqntSXE-10      17.14.11  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...
# WuTFI5qftCE      17.14.11                    PAPY GRENIER - METAL GEAR SOLID
# ee6OFs8TdEg      17.14.11  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...
# ...                   ...                                                ...
# coVXf3Q9xBk      18.14.06  عاجل و رسمي : الملف الأمريكي يفوز بشرف تنظيم ك...
# _umkjOQJvtw      18.14.06  شاهد ملخص البرلمان اليوم بحضور اخنوش الدي يعطي...
# nt25ec7nzIM      18.14.06              UN ANIME EXPLOSIF A VOIR ABSOLUMENT !
# NlxE_QQMRzg      18.14.06  Նռան հատիկ, Սերիա 192 / Pomegranate seed / Nra...
# _LgKglfnqlc      18.14.06              Mandoumbé ak Koor Gui 2018 Episode 28
#
#                    channel_title  category_id              publish_time  \
# video_id
# Ro6eob0LrCY  Le Raptor Dissident           24  2017-11-13T17:32:55.000Z
# Yo84eqYwP98              Le Labo           24  2017-11-12T15:00:02.000Z
# ceqntSXE-10      Daniil le Russe           23  2017-11-13T17:00:38.000Z
# WuTFI5qftCE    Joueur Du Grenier           20  2017-11-12T17:00:02.000Z
# ee6OFs8TdEg    Aurelien Fontenoy           17  2017-11-13T16:30:03.000Z
# ...                          ...          ...                       ...
# coVXf3Q9xBk          KORA LOVERS            1  2018-06-13T12:31:04.000Z
# _umkjOQJvtw            Jadal جدل           25  2018-06-12T17:51:24.000Z
# nt25ec7nzIM            RushManga           22  2018-06-13T11:50:18.000Z
# NlxE_QQMRzg       PanArmenian TV            1  2018-06-13T18:30:00.000Z
# _LgKglfnqlc             Yesdakar           24  2018-06-13T19:45:14.000Z
#
#                                                           tags   views  likes  \
# video_id
# Ro6eob0LrCY  Raptor"|"Dissident"|"Expliquez"|"moi"|"cette"|...  212702  29282
# Yo84eqYwP98                                             [none]  432721  14053
# ceqntSXE-10      cartoon"|"pokémon"|"école"|"ours"|"мультфильм  482153  76203
# WuTFI5qftCE  Papy grenier"|"Metal Gear Solid"|"PS1"|"Tirage...  925222  85016
# ee6OFs8TdEg  vélo"|"vtt"|"bmx"|"freestyle"|"bike"|"mtb"|"di...  141695   8091
# ...                                                        ...     ...    ...
# coVXf3Q9xBk  تنظيم كأس العالم 2026|"كأس العالم 2026"|"المغر...   58758    307
# _umkjOQJvtw  الباكالوريا في المغرب|"صحاب الباك"|"صحاب الباك...  264639   2011
# nt25ec7nzIM  RushManga|"rush manga"|"anime a voir"|"UN ANIM...   47510   4601
# NlxE_QQMRzg  Նռան հատիկ|"Սերիա 192"|"Pomegranate seed"|"Nra...   78117    244
# _LgKglfnqlc                  ramadan2018|"koorgui"|"Mandoumbé"   46604    947
#
#              dislikes  comment_count  \
# video_id
# Ro6eob0LrCY      1108           3817
# Yo84eqYwP98       576           1161
# ceqntSXE-10       477           9580
# WuTFI5qftCE       550           4303
# ee6OFs8TdEg        72            481
# ...               ...            ...
# coVXf3Q9xBk        86            485
# _umkjOQJvtw       999           1397
# nt25ec7nzIM        61            615
# NlxE_QQMRzg        74             46
# _LgKglfnqlc        37            127
#
#                                              thumbnail_link  \
# video_id
# Ro6eob0LrCY  https://i.ytimg.com/vi/Ro6eob0LrCY/default.jpg
# Yo84eqYwP98  https://i.ytimg.com/vi/Yo84eqYwP98/default.jpg
# ceqntSXE-10  https://i.ytimg.com/vi/ceqntSXE-10/default.jpg
# WuTFI5qftCE  https://i.ytimg.com/vi/WuTFI5qftCE/default.jpg
# ee6OFs8TdEg  https://i.ytimg.com/vi/ee6OFs8TdEg/default.jpg
# ...                                                     ...
# coVXf3Q9xBk  https://i.ytimg.com/vi/coVXf3Q9xBk/default.jpg
# _umkjOQJvtw  https://i.ytimg.com/vi/_umkjOQJvtw/default.jpg
# nt25ec7nzIM  https://i.ytimg.com/vi/nt25ec7nzIM/default.jpg
# NlxE_QQMRzg  https://i.ytimg.com/vi/NlxE_QQMRzg/default.jpg
# _LgKglfnqlc  https://i.ytimg.com/vi/_LgKglfnqlc/default.jpg
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# video_id
# Ro6eob0LrCY              False             False                   False
# Yo84eqYwP98              False             False                   False
# ceqntSXE-10              False             False                   False
# WuTFI5qftCE              False             False                   False
# ee6OFs8TdEg              False             False                   False
# ...                        ...               ...                     ...
# coVXf3Q9xBk              False             False                   False
# _umkjOQJvtw              False             False                   False
# nt25ec7nzIM              False             False                   False
# NlxE_QQMRzg              False             False                   False
# _LgKglfnqlc              False             False                   False
#
#                                                    description  \
# video_id
# Ro6eob0LrCY  Dimanche.\n18h30.\nSoyez présents pour la vidé...
# Yo84eqYwP98  Le jeu de société: https://goo.gl/hhG1Ta\n\nGa...
# ceqntSXE-10  Une nouvelle dose de dessins animés français e...
# WuTFI5qftCE  Nouvel ,épisode de Papy Grenier ! Ce mois-ci o...
# ee6OFs8TdEg  Sauts à plus de 4 mètres de haut dans un tramp...
# ...                                                        ...
# coVXf3Q9xBk  المغرب تخسر تنظيم مونديال كاس العالم 2026 لصال...
# _umkjOQJvtw  ملخص ابرز ما حصل في جلسة البرلمان يوم 12/06/20...
# nt25ec7nzIM  •● Yozakura Quartet ~Hana no Uta~ ●•☆ S'abonne...
# NlxE_QQMRzg  Follow Armenia TV on social platforms:Instagra...
# _LgKglfnqlc                                                NaN
#
#                      category
# video_id
# Ro6eob0LrCY     Entertainment
# Yo84eqYwP98     Entertainment
# ceqntSXE-10            Comedy
# WuTFI5qftCE            Gaming
# ee6OFs8TdEg            Sports
# ...                       ...
# coVXf3Q9xBk  Film & Animation
# _umkjOQJvtw   News & Politics
# nt25ec7nzIM    People & Blogs
# NlxE_QQMRzg  Film & Animation
# _LgKglfnqlc     Entertainment
#
# [40724 rows x 16 columns]

# %%
data_us["category"] = ""
for x in range(len(list_cat_us)):
    filtre = data_us["category_id"] == x
    data_us["category"][filtre] = list_cat_us[x]
data_us.category.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-2a59a4b9259c> in <module>
#       1 data_us["category"] = ""
# ----> 2 for x in range(len(list_cat_us)):
#       3     filtre = data_us["category_id"] == x
#       4     data_us["category"][filtre] = list_cat_us[x]
#       5 data_us.category.values
#
# NameError: name 'list_cat_us' is not defined

# %%
data_fr[data_fr["category_id"] == 26]
# Out:
#             trending_date                                              title  \
# video_id
# RpEJCznFreQ      17.14.11              FAIRE UNE GLACE ROULÉE (sans machine)
# avNyRo2Vd9U      17.14.11  10 RECETTES DIY DE BAUME À LÈVRES À PARTIR DE ...
# ko1ebVo3C70      17.14.11  20 ASTUCES DE GENIE POUR L'ECOLE QUE VOUS AURI...
# 1SiKopOt-QM      17.14.11   26 SIMPLE WAYS TO SPEED UP YOUR EVERYDAY ROUTINE
# BaPXooxJp00      17.14.11            Je réinspire ma vie - GEORGIA HORACKOVA
# ...                   ...                                                ...
# FYdIZP_o77s      18.14.06        ♡• SÉLÉCTIONNÉE POUR LA COUPE DU MONDE ? •♡
# PStvIRCJWU4      18.14.06              30 ASTUCES QUE LES FILLES VONT ADORER
# JTrOlNOp0iA      18.14.06               Club sandwich poulet bacon - Youcook
# VU5CEdBAYPA      18.14.06  بدأ العد العكسي😱زينت بيتي بديكورات لإستقبال ال...
# AIyy55-WBkc      18.14.06         حلويات العيد بمكونات إقتصادية وبكمية كتيرة
#
#                        channel_title  category_id              publish_time  \
# video_id
# RpEJCznFreQ         Alexandre Calvez           26  2017-11-12T18:00:02.000Z
# avNyRo2Vd9U           Troom Troom FR           26  2017-11-13T13:00:01.000Z
# ko1ebVo3C70         Le Saviez-Vous ?           26  2017-11-13T16:27:46.000Z
# 1SiKopOt-QM          5-Minute Crafts           26  2017-11-13T16:30:00.000Z
# BaPXooxJp00        Georgia Horackova           26  2017-11-12T18:25:11.000Z
# ...                              ...          ...                       ...
# FYdIZP_o77s      L'atelier de Roxane           26  2018-06-13T10:00:02.000Z
# PStvIRCJWU4              BRICO SYMPA           26  2018-06-13T10:35:13.000Z
# JTrOlNOp0iA          YouCook Cuisine           26  2018-06-12T15:30:01.000Z
# VU5CEdBAYPA  Malak World - عالم ملاك           26  2018-06-13T14:38:35.000Z
# AIyy55-WBkc             Asmaa Beauty           26  2018-06-13T18:42:43.000Z
#
#                                                           tags   views  likes  \
# video_id
# RpEJCznFreQ  Alexandre Calvez"|"Crash Test"|"Alexandre"|"Ca...  373013  23645
# avNyRo2Vd9U  DIY"|"baume à lèvres maison"|"EOS"|"gommage"|"...  240158   6765
# ko1ebVo3C70  DIY"|"faites le vous même"|"la guerre des blag...   24072   2127
# 1SiKopOt-QM  5-Minute Crafts"|"DIY"|"Do it yourself"|"craft...  803400  15547
# BaPXooxJp00  georgia horackova"|"inspiration"|"challenge"|"...  102674  11082
# ...                                                        ...     ...    ...
# FYdIZP_o77s  recette foot|"recette football"|"coupe du mond...  252034  22074
# PStvIRCJWU4  Brico Sympa|"Fait-Maison"|"Fait-main"|"Bricola...   29933    626
# JTrOlNOp0iA  youcook|"cuisine"|"recette"|"video youcook"|"c...   63468   4326
# VU5CEdBAYPA  حلويات سهلة|"حلويات سهلة وسريعة"|"حلويات بدون ...   37211   2569
# AIyy55-WBkc  Asmaa|"Asmaa beauty"|"Maroc"|"Beauty"|"Ramadan...  125023   9142
#
#              dislikes  comment_count  \
# video_id
# RpEJCznFreQ       411            813
# avNyRo2Vd9U       160            935
# ko1ebVo3C70       158            306
# 1SiKopOt-QM      1130            955
# BaPXooxJp00       256            681
# ...               ...            ...
# FYdIZP_o77s       356           2125
# PStvIRCJWU4        57             77
# JTrOlNOp0iA        49            235
# VU5CEdBAYPA        71            237
# AIyy55-WBkc       213           1642
#
#                                              thumbnail_link  \
# video_id
# RpEJCznFreQ  https://i.ytimg.com/vi/RpEJCznFreQ/default.jpg
# avNyRo2Vd9U  https://i.ytimg.com/vi/avNyRo2Vd9U/default.jpg
# ko1ebVo3C70  https://i.ytimg.com/vi/ko1ebVo3C70/default.jpg
# 1SiKopOt-QM  https://i.ytimg.com/vi/1SiKopOt-QM/default.jpg
# BaPXooxJp00  https://i.ytimg.com/vi/BaPXooxJp00/default.jpg
# ...                                                     ...
# FYdIZP_o77s  https://i.ytimg.com/vi/FYdIZP_o77s/default.jpg
# PStvIRCJWU4  https://i.ytimg.com/vi/PStvIRCJWU4/default.jpg
# JTrOlNOp0iA  https://i.ytimg.com/vi/JTrOlNOp0iA/default.jpg
# VU5CEdBAYPA  https://i.ytimg.com/vi/VU5CEdBAYPA/default.jpg
# AIyy55-WBkc  https://i.ytimg.com/vi/AIyy55-WBkc/default.jpg
#
#              comments_disabled  ratings_disabled  video_error_or_removed  \
# video_id
# RpEJCznFreQ              False             False                   False
# avNyRo2Vd9U              False             False                   False
# ko1ebVo3C70              False             False                   False
# 1SiKopOt-QM              False             False                   False
# BaPXooxJp00              False             False                   False
# ...                        ...               ...                     ...
# FYdIZP_o77s              False             False                   False
# PStvIRCJWU4              False             False                   False
# JTrOlNOp0iA              False             False                   False
# VU5CEdBAYPA              False             False                   False
# AIyy55-WBkc              False             False                   False
#
#                                                    description       category
# video_id
# RpEJCznFreQ  👉 Ma page facebook : https://facebook.com/alex...  Howto & Style
# avNyRo2Vd9U  Abonnez-vous ici : http://bit.ly/2vnYmfc\n12 B...  Howto & Style
# ko1ebVo3C70  20 ASTUCES DE GENIE POUR L'ECOLE QUE VOUS AURI...  Howto & Style
# 1SiKopOt-QM  Subscribe to 5-Minute Crafts KIDS: https://goo...  Howto & Style
# BaPXooxJp00  ---------------------------------👇-- DÉROULE M...  Howto & Style
# ...                                                        ...            ...
# FYdIZP_o77s  •♡• Pour cette semaine spéciale coupe du monde...  Howto & Style
# PStvIRCJWU4  Apprends à réaliser des masques pour le visage...  Howto & Style
# JTrOlNOp0iA  Ingrédients :- Pain de mie, poulet, bacon, avo...  Howto & Style
# VU5CEdBAYPA  بدأ العد العكسي😱زينت بيتي بديكورات لإستقبال ال...  Howto & Style
# AIyy55-WBkc  تابعوني أيضا على الشبكات الاجتماعية:       * F...  Howto & Style
#
# [2361 rows x 16 columns]

# %%
data_fr[data_fr["category"] == "Howto & Style"].shape
# Out:
# (2361, 16)

# %% [markdown]
# ## Graphs par catégories

# %% [markdown]
# #### Nouveau DataFrame allégé

# %%
df = data_fr[["title", "category", "views", "likes", "dislikes", "comment_count"]]

# %%
df.head()
# Out:
#                                                          title       category  \
# video_id
# Ro6eob0LrCY           Malika LePen : Femme de Gauche - Trailer  Entertainment
# Yo84eqYwP98  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...  Entertainment
# ceqntSXE-10  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...         Comedy
# WuTFI5qftCE                    PAPY GRENIER - METAL GEAR SOLID         Gaming
# ee6OFs8TdEg  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...         Sports
#
#               views  likes  dislikes  comment_count
# video_id
# Ro6eob0LrCY  212702  29282      1108           3817
# Yo84eqYwP98  432721  14053       576           1161
# ceqntSXE-10  482153  76203       477           9580
# WuTFI5qftCE  925222  85016       550           4303
# ee6OFs8TdEg  141695   8091        72            481

# %%
df.groupby(by="category").describe()
# Out:
#                        views                                                 \
#                        count          mean           std     min        25%
# category
#                        114.0  5.218433e+05  2.430685e+06  1420.0    4420.25
# Autos & Vehicles       673.0  6.502963e+04  2.808704e+05  1078.0    4644.00
# Comedy                4343.0  4.366301e+05  7.616110e+05   385.0   46863.50
# Education              769.0  1.570124e+05  3.021652e+05   640.0    6806.00
# Entertainment         9819.0  3.849170e+05  1.860882e+06   223.0   27157.50
# Film & Animation      2157.0  4.258308e+05  1.478270e+06   887.0   18044.00
# Gaming                1459.0  3.064840e+05  8.912511e+05   528.0   22314.50
# Howto & Style         2361.0  1.983670e+05  6.639337e+05   404.0    7742.00
# Movies                  11.0  9.347400e+04  2.290961e+05  9822.0   12061.00
# Music                 3946.0  1.273808e+06  3.954629e+06   920.0   51032.25
# News & Politics       3752.0  1.319418e+05  3.994979e+05   274.0    9235.50
# People & Blogs        5719.0  2.239628e+05  1.142457e+06   543.0   10730.50
# Pets & Animals         237.0  1.828660e+05  7.520963e+05   743.0    4381.00
# Science & Technology   802.0  5.760502e+05  2.007040e+06   630.0   17802.75
# Shows                   99.0  5.234737e+05  1.708457e+05  4904.0  447106.00
# Sports                4342.0  4.598828e+05  1.250986e+06   374.0   21246.75
# Trailers                 2.0  6.470000e+03  4.714988e+03  3136.0    4803.00
# Travel & Events        119.0  8.192504e+04  1.943802e+05   944.0    5656.00
#
#                                                          likes                \
#                            50%        75%          max   count          mean
# category
#                        10393.0   51094.50   19092511.0   114.0  52520.912281
# Autos & Vehicles       19055.0   70463.00    6793122.0   673.0   2387.469539
# Comedy                154879.0  499785.00    9407979.0  4343.0  30118.683859
# Education              28888.0  200012.00    2689851.0   769.0  10796.676203
# Entertainment          96072.0  289114.00  100911567.0  9819.0  12042.322029
# Film & Animation       77826.0  199353.00   22762717.0  2157.0  11419.296245
# Gaming                 61823.0  169325.50   11880523.0  1459.0  15423.374914
# Howto & Style          25936.0  153121.00   10883016.0  2361.0   6573.330368
# Movies                 16801.0   33676.00     781977.0    11.0   2208.636364
# Music                 209371.5  796261.75   65396157.0  3946.0  70277.302078
# News & Politics        26115.5   93103.50    7906164.0  3752.0   2479.074094
# People & Blogs         37828.0  151965.50   44818108.0  5719.0   5058.175380
# Pets & Animals         13730.0   47832.00    7220717.0   237.0   5634.805907
# Science & Technology   88244.5  389479.25   29403688.0   802.0  23084.320449
# Shows                 511645.0  607078.50    1268075.0    99.0   2941.535354
# Sports                 88995.0  372579.50   20761480.0  4342.0  10125.416859
# Trailers                6470.0    8137.00       9804.0     2.0     96.000000
# Travel & Events        10782.0   46754.00    1150661.0   119.0   7325.831933
#
#                       ... dislikes            comment_count                \
#                       ...      75%        max         count          mean
# category              ...
#                       ...    55.00   398361.0         114.0  16215.728070
# Autos & Vehicles      ...    80.00     5893.0         673.0    309.023774
# Comedy                ...   647.00    33678.0        4343.0   2103.802441
# Education             ...   289.00     9515.0         769.0    998.795839
# Entertainment         ...   355.00  1353661.0        9819.0   1601.988390
# Film & Animation      ...   238.00    52292.0        2157.0   1317.410756
# Gaming                ...   318.00   164004.0        1459.0   2088.823167
# Howto & Style         ...   211.00    21627.0        2361.0    745.174926
# Movies                ...    36.00      783.0          11.0    133.363636
# Music                 ...  1107.25   141966.0        3946.0   6448.628738
# News & Politics       ...   126.00    37610.0        3752.0    505.357409
# People & Blogs        ...   200.00    71750.0        5719.0    717.751005
# Pets & Animals        ...    49.00     9334.0         237.0    791.518987
# Science & Technology  ...   631.50    24543.0         802.0   3648.831671
# Shows                 ...  1098.00     4294.0          99.0    453.353535
# Sports                ...   296.00   117128.0        4342.0   1053.758176
# Trailers              ...     6.75        9.0           2.0      0.000000
# Travel & Events       ...    71.00     1068.0         119.0    856.235294
#
#
#                                std   min     25%    50%      75%        max
# category
#                       84340.250469   0.0    0.25   10.0   118.50   611327.0
# Autos & Vehicles        517.150842   0.0   17.00   84.0   397.00     4462.0
# Comedy                 7445.619356   0.0  146.00  482.0  1520.00   315801.0
# Education              2180.862263   0.0   41.00  201.0  1115.00    25513.0
# Entertainment         14793.618033   0.0   63.00  261.0   804.00   827755.0
# Film & Animation       3864.993448   0.0   57.00  201.0   845.00    44215.0
# Gaming                 7272.304931   0.0   64.50  288.0   952.00   115501.0
# Howto & Style          2177.981648   0.0   62.00  195.0   770.00    54811.0
# Movies                  319.399835  17.0   33.00   42.0    44.50     1096.0
# Music                 32902.395201   0.0  150.00  679.0  2825.75  1040912.0
# News & Politics        2133.049302   0.0   29.00  103.0   339.00    64291.0
# People & Blogs         5269.481411   0.0   31.00  119.0   431.00   264405.0
# Pets & Animals         3619.682621   0.0   33.00  108.0   381.00    34224.0
# Science & Technology   9887.703917   0.0  144.00  570.0  2112.75   141646.0
# Shows                   307.778224  19.0  285.00  355.0   566.50     2566.0
# Sports                 3431.727847   0.0   46.00  241.0   692.50    51412.0
# Trailers                  0.000000   0.0    0.00    0.0     0.00        0.0
# Travel & Events        2541.878315   0.0   27.50  110.0   310.50    15008.0
#
# [18 rows x 32 columns]

# %% [markdown]
# ### Reduction du jeu de donnéés

# %% [markdown]
# ##### 200 entrées

# %%
#df = df.iloc[0:200, :]

# %%
df.shape
# Out:
# (40724, 6)

# %% [markdown]
# ### Views / Catégories

# %%
df.category.unique().shape
# Out:
# (18,)

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["views"])
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de vues / Catégories", size=35)

plt.show()

# %% [markdown]
# ### Likes / Catégories

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["likes"], color="g")
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de likes / Catégories", size=35)

plt.show()

# %% [markdown]
# ### Dislikes / Catégories

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["dislikes"], color="r")
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de dislikes / Catégories", size=35)

plt.show()

# %% [markdown]
# ### Comments / Catégories

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["comment_count"], color="y")
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de commentaires / Catégories", size=35)

plt.show()

# %%
df = df.iloc[0:200, :]

# %%
plt.figure(figsize=(18,8))

#plt.bar(df["category"], df["views"])
plt.bar(df["category"], df["likes"], width=0.3, align="edge", color="g")
plt.bar(df["category"], df["dislikes"], width=-0.3, align="edge", color="r")
plt.bar(df["category"], df["comment_count"], width=0.3, align="center", color="y")


plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.ylim(0,120000)

plt.title("Nombre de likes, dislikes, comment / Catégories", size=35)

plt.show()

# %% [markdown]
# ## Travail sur les mots-clés

# %% [markdown]
# ### DataFrame allégé

# %%
df = data_fr.copy()
#df = df[0:200]
df.shape

# %% [markdown]
# #### Création d'un dictionnaire de mots-cles

# %%
tags = df["tags"].values

# %%
def supprime_accent(ligne):
        """ supprime les accents du texte source """
        accent = ['é', 'è', 'ê', 'à', 'ù', 'û', 'ç', 'ô', 'î', 'ï', 'â']
        sans_accent = ['e', 'e', 'e', 'a', 'u', 'u', 'c', 'o', 'i', 'i', 'a']
        i = 0
        while i < len(accent):
            ligne = ligne.replace(accent[i], sans_accent[i])
            i += 1
        return ligne

# %%
liste_tags = []
for y in tags:
    y = y.lower()
    result = supprime_accent(y)
    result = result.split('"|"')
    liste_tags.append(result)

# %%
dico_tags = {}
for x in liste_tags:
    for x in x:
        if x in dico_tags.keys():
            dico_tags[x] += 1
        else:
            dico_tags[x] = 1

# %%
len(dico_tags.keys())

# %% [markdown]
# #### Classement du dico

# %%
dico_tags_sorted = sorted(dico_tags.items(),key=lambda c:c[1], reverse=True)
dico_tags_sorted

# %%
mot = "humour"
filtre = df["tags"].str.contains(mot)
data_fr[filtre].shape

# %%
a = data_fr["tags"][data_fr.index == "kn-pu9awJaY"].values
print(a)

# %%
dico_tags.sort()

# %%
for key, val in sorted(dico_tags, key=dico_tags.values()):
    print(key, val)


#sorted(dico_tags.values(), reverse=True)
