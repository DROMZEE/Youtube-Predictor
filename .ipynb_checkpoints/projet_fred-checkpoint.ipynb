# %% [markdown]
# # Projet 2 - Youtube --Fred--

# %% [markdown]
# ### Import des modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import des données

# %% [markdown]
# ##### Data

# %%
data_fr = pd.read_csv("data/modif_FRvideos.csv")
# Out:
# /home/fred/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_fr.dtypes
# Out:
# video_id                   object
# trending_date              object
# title                      object
# channel_title              object
# category_id               float64
# publish_time               object
# tags                       object
# views                     float64
# likes                     float64
# dislikes                  float64
# comment_count             float64
# thumbnail_link             object
# comments_disabled          object
# ratings_disabled           object
# video_error_or_removed     object
# description                object
# category                   object
# engagement                float64
# duree                     float64
# dtype: object

# %%
print(data_fr.shape)
data_fr.head(2)
# Out:
# (40854, 19)
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
#
#    category_id              publish_time  \
# 0         24.0  2017-11-13T17:32:55.000Z
# 1         24.0  2017-11-12T15:00:02.000Z
#
#                                                 tags     views    likes  \
# 0  Raptor"|"Dissident"|"Expliquez"|"moi"|"cette"|...  212702.0  29282.0
# 1                                             [none]  432721.0  14053.0
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0    1108.0         3817.0  https://i.ytimg.com/vi/Ro6eob0LrCY/default.jpg
# 1     576.0         1161.0  https://i.ytimg.com/vi/Yo84eqYwP98/default.jpg
#
#   comments_disabled ratings_disabled video_error_or_removed  \
# 0             False            False                  False
# 1             False            False                  False
#
#                                          description       category  \
# 0  Dimanche.\n18h30.\nSoyez présents pour la vidé...  Entertainment
# 1  Le jeu de société: https://goo.gl/hhG1Ta\n\nGa...  Entertainment
#
#    engagement   duree
# 0    0.077777     NaN
# 1    0.029909  3541.0

# %% [markdown]
# ## Graphs par catégories

# %% [markdown]
# #### Nouveau DataFrame allégé

# %%
df = data_fr[["title", "category", "duree", "engagement", "views", "likes", "dislikes", "comment_count"]]

# %%
df.tail(2)
# Out:
#                                                    title          category  \
# 40852  Նռան հատիկ, Սերիա 192 / Pomegranate seed / Nra...  Film & Animation
# 40853              Mandoumbé ak Koor Gui 2018 Episode 28     Entertainment
#
#         duree  engagement    views  likes  dislikes  comment_count
# 40852  2257.0    0.003712  78117.0  244.0      74.0           46.0
# 40853   454.0    0.023045  46604.0  947.0      37.0          127.0

# %% [markdown]
# ### Reduction du jeu de donnéés

# %% [markdown]
# ##### 200 entrées

# %%
#df = df.iloc[0:200, :]

# %%
df.shape
# Out:
# (40854, 8)

# %% [markdown]
# ### Views / Catégories

# %%
df.category.unique()
# Out:
# array(['Entertainment', 'Comedy', 'Gaming', 'Sports', 'People & Blogs',
#        'Education', 'Howto & Style', 'Science & Technology',
#        'Autos & Vehicles', 'News & Politics', 'Film & Animation', 'Music',
#        'Shows', 'Travel & Events', 'Pets & Animals', nan, 'Movies',
#        'Trailers'], dtype=object)

# %%
df.shape
# Out:
# (40854, 8)

# %%
df = df[~df["category"].isnull()]

# %%
df.shape
# Out:
# (40593, 8)

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["views"])
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de vues / Catégories", size=35)

plt.show()

# %% [markdown]
# ### Likes / Catégories

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["likes"], color="g")
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de likes / Catégories", size=35)

plt.show()

# %% [markdown]
# ### Dislikes / Catégories

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["dislikes"], color="r")
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de dislikes / Catégories", size=35)

plt.show()

# %% [markdown]
# ### Comments / Catégories

# %%
plt.figure(figsize=(18,8))

plt.bar(df["category"], df["comment_count"], color="y")
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Nombre de commentaires / Catégories", size=35)

plt.show()

# %% [markdown]
# ### Groupé

# %%
plt.figure(figsize=(16,6))

#plt.bar(df["category"], df["views"])
plt.bar(df["category"], df["likes"],label="Likes", width=0.3, align="edge", color="g")
plt.bar(df["category"], df["dislikes"],label="Dislikes", width=-0.3, align="edge", color="r")
plt.bar(df["category"], df["comment_count"],label="Comments", width=0.3, align="center", color="y")


plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.ylim(0,1200000)

plt.title("Nombre de likes, dislikes, comment / Catégories", size=35)
plt.legend(loc="best", bbox_to_anchor=(1,1))

plt.show()

# %% [markdown]
# ## Travail sur les mots-clés

# %% [markdown]
# ### DataFrame allégé

# %%
df = data_fr.copy()
#df = df[0:200]
df.shape
# Out:
# (40854, 19)

# %%
df = df[~df["tags"].isnull()]

# %% [markdown]
# #### Création d'un dictionnaire de mots-cles

# %%
tags = df["tags"].values

# %%
def supprime_accent(ligne):
        """ supprime les accents du texte source """
        accent = ['é', 'è', 'ê', 'à', 'ù', 'û', 'ç', 'ô', 'î', 'ï', 'â']
        sans_accent = ['e', 'e', 'e', 'a', 'u', 'u', 'c', 'o', 'i', 'i', 'a']
        i = 0
        while i < len(accent):
            ligne = ligne.replace(accent[i], sans_accent[i])
            i += 1
        return ligne

# %%
tags[0:1]
# Out:
# array(['Raptor"|"Dissident"|"Expliquez"|"moi"|"cette"|"merde'],
#       dtype=object)

# %%
liste_tags = []
for y in tags:
    y = y.lower()
    result = supprime_accent(y)
    result = result.split('"|"')
    liste_tags.append(result)

# %%
dico_tags = {}
for x in liste_tags:
    for x in x:
        if x in dico_tags.keys():
            dico_tags[x] += 1
        else:
            dico_tags[x] = 1

# %%
len(dico_tags.keys())
# Out:
# 125790

# %% [markdown]
# #### Classement du dico

# %%
dico_tags_sorted = sorted(dico_tags.items(),key=lambda c:c[1], reverse=True)
dico_tags_sorted
# Out:
# [('[none]', 5304),
#  ('humour', 2279),
#  ('football', 1433),
#  ('2018', 1433),
#  ('france', 1374),
#  ('video', 1104),
#  ('rap', 969),
#  ('drole', 888),
#  ('tv', 819),
#  ('francais', 812),
#  ('serie', 761),
#  ('paris', 736),
#  ('live', 728),
#  ('divertissement', 681),
#  ('freestyle', 672),
#  ('musique', 669),
#  ('foot', 650),
#  ('2017', 626),
#  ('interview', 602),
#  ('funny', 589),
#  ('senegal', 559),
#  ('sketch', 555),
#  ('film', 553),
#  ('music', 549),
#  ('psg', 531),
#  ('comedy', 519),
#  ('sport', 514),
#  ('fr', 511),
#  ('maroc', 502),
#  ('amour', 500),
#  ('johnny hallyday', 499),
#  ('top 10', 491),
#  ('television', 482),
#  ('vlog', 468),
#  ('politique', 465),
#  ('tuto', 453),
#  ('youtube', 450),
#  ('news', 449),
#  ('replay', 446),
#  ('comedie', 444),
#  ('highlights', 434),
#  ('neymar', 430),
#  ('rire', 427),
#  ('clip', 420),
#  ('theatre', 420),
#  ('cinema', 417),
#  ('top', 417),
#  ('fun', 416),
#  ('prank', 415),
#  ('zap', 411),
#  ('tpmp', 405),
#  ('booba', 404),
#  ('diy', 387),
#  ('macron', 387),
#  ('ronaldo', 368),
#  ('de', 363),
#  ('clash', 359),
#  ('astuces', 359),
#  ('couple', 354),
#  ('rap francais', 353),
#  ('messi', 347),
#  ('tele realite', 344),
#  ('tf1', 342),
#  ('recette', 341),
#  ('challenge', 333),
#  ('marseille', 331),
#  ('parodie', 330),
#  ('entertainment', 329),
#  ('people', 329),
#  ('algerie', 328),
#  ('france 2', 327),
#  ('resume', 319),
#  ('famille', 317),
#  ('test', 315),
#  ('hip hop', 315),
#  ('defi', 312),
#  ('cuisine', 309),
#  ('real madrid', 308),
#  ('compilation', 305),
#  ('telefilm', 303),
#  ('المغرب', 302),
#  ('radio', 302),
#  ('pop', 299),
#  ('les anges 10', 298),
#  ('actu', 297),
#  ('zapping', 296),
#  ('blague', 296),
#  ('hd', 292),
#  ('actualite', 284),
#  ('humor', 283),
#  ('reaction', 281),
#  ('afrique', 281),
#  ('tutoriel', 279),
#  ('french', 276),
#  ('incroyable', 275),
#  ('tfm', 272),
#  ('insolite', 269),
#  ('cyril hanouna', 267),
#  ('tutorial', 266),
#  ('laeticia hallyday', 264),
#  ('niska', 260),
#  ('trump', 258),
#  ('le', 256),
#  ('nba', 256),
#  ('france televisions', 255),
#  ('mort', 255),
#  ('soccer', 254),
#  ('tunisie', 254),
#  ('new', 253),
#  ('talk show', 253),
#  ('celebrities', 252),
#  ('maitre gims', 250),
#  ('bricolage', 250),
#  ('emmanuel macron', 248),
#  ('critique', 248),
#  ('idoles', 247),
#  ('fail', 244),
#  ('match', 244),
#  ('podcast', 241),
#  ('moto', 241),
#  ('videos', 240),
#  ('comedian', 240),
#  ('vie', 237),
#  ('funny video', 237),
#  ('documentaire', 235),
#  ('emission', 234),
#  ('but', 234),
#  ('johnny', 232),
#  ('les marseillais', 228),
#  ('الجزائر', 227),
#  ('touche pas a mon poste', 227),
#  ('damso', 226),
#  ('2stv', 225),
#  ('ligue 1', 225),
#  ('buzz', 224),
#  ('science', 223),
#  ('education', 223),
#  ('reportage', 222),
#  ('fortnite', 219),
#  ('enfant', 218),
#  ('noel', 218),
#  ('laurent ruquier', 217),
#  ('show', 217),
#  ('vs', 216),
#  ('love', 216),
#  ('golden moustache', 214),
#  ('comment', 213),
#  ('la', 213),
#  ('episode', 212),
#  ('labes', 212),
#  ('عندي ما نقلك', 212),
#  ('dakar', 212),
#  ('police', 212),
#  ('ninho', 212),
#  ('andi mankolek', 211),
#  ('best', 211),
#  ('denya okhra', 210),
#  ('karim el gharbi', 210),
#  ('oumour jedia', 209),
#  ('c8', 208),
#  ('dari deco', 208),
#  ('360 degrees', 208),
#  ('klem ennes', 208),
#  ('ma binetna', 208),
#  ('lacrim', 208),
#  ('#youtube', 208),
#  ('oumour jeddya', 207),
#  ('happy nes', 207),
#  ('maktoub', 207),
#  ('facile', 207),
#  ('coupe du monde', 206),
#  ('enfants', 206),
#  ('nouveau', 205),
#  ('liman yajroo fakat', 205),
#  ('labas', 205),
#  ('awled mofida', 205),
#  ('el hak maak', 205),
#  ('wled moufida', 205),
#  ('awled moufida', 205),
#  ('اليوم الثامن', 205),
#  ('مكتوب', 205),
#  ('أمور جدّية', 205),
#  ('om', 205),
#  ('bande annonce', 204),
#  ('les marseillais australia', 204),
#  ('histoire', 201),
#  ('animaux', 201),
#  ('monde', 200),
#  ('food', 200),
#  ('تونس', 198),
#  ('funny videos', 198),
#  ('mariage', 198),
#  ('teaser', 197),
#  ('jul', 196),
#  ('gameplay', 195),
#  ('actualites', 195),
#  ('buts', 195),
#  ('ramadan', 195),
#  ('wtf', 194),
#  ('review', 193),
#  ('joke', 193),
#  ('the voice', 193),
#  ('sam zirah', 192),
#  ('art', 192),
#  ('jeremstar', 191),
#  ('star', 191),
#  ('youtuber', 190),
#  ('sante', 189),
#  ('les', 189),
#  ('أولاد مفيده', 188),
#  ('sports', 187),
#  ('donald trump', 186),
#  ('lol', 186),
#  ('late night', 186),
#  ('greg guillotin', 186),
#  ('wled mofida', 185),
#  ('animation', 183),
#  ('yerli dizi hd izle', 183),
#  ('sami fehri', 183),
#  ('mbettel', 182),
#  ('nhar lahad ma hemek fi had', 181),
#  ('نهار الأحد ما يهمّك في حدّ', 181),
#  ('نهار الأحد', 181),
#  ('delire', 181),
#  ('cover', 181),
#  ('trailer', 180),
#  ('debat', 180),
#  ('suntv', 180),
#  ('لا بــــاس', 180),
#  ('hollywood', 180),
#  ('les grosses tetes', 180),
#  ('noël', 180),
#  ('les anges', 178),
#  ('hallyday', 178),
#  ('best of', 177),
#  ('snapchat', 177),
#  ('jeux', 175),
#  ('info', 175),
#  ('islam', 174),
#  ('pas', 174),
#  ('top 5', 173),
#  ('fifa 18', 173),
#  ('melenchon', 171),
#  ('vald', 171),
#  ('pnl', 170),
#  ('youssou ndour;musique', 169),
#  ('sp:ty=high', 169),
#  ('lyon', 168),
#  ('tendances', 167),
#  ('أخبار', 167),
#  ('tele', 167),
#  ('fally ipupa', 166),
#  ('dadju', 166),
#  ('grand', 165),
#  ('fianso', 165),
#  ('decouverte', 165),
#  ('youtubeuse', 165),
#  ('exclu', 163),
#  ('tunisia', 163),
#  ('dance', 162),
#  ('jeu', 162),
#  ('presse', 162),
#  ('vf', 162),
#  ('elhiwar ettounsi', 161),
#  ('atv', 161),
#  ('direct', 161),
#  ('sylvie vartan', 161),
#  ('chanson', 159),
#  ('canal+', 159),
#  ('beaute', 159),
#  ('spectacle', 158),
#  ('w9', 158),
#  ('skyrock', 158),
#  ('voiture', 157),
#  ('en', 157),
#  ('instagram', 157),
#  ('snapchat red', 157),
#  ('lifestyle', 156),
#  ('ay yapım', 156),
#  ('türkiye', 156),
#  ('jokes', 156),
#  ('yeni dizi', 156),
#  ('mhd', 156),
#  ('cukur fragman', 155),
#  ('aras bulut iynemli', 155),
#  ('dilan cicek deniz', 155),
#  ('hkayet tounsia', 155),
#  ('vincent queijo', 155),
#  ('trucs', 155),
#  ('degustation', 154),
#  ('disney', 153),
#  ('gag', 153),
#  ('guillaume pley', 153),
#  ('morocco', 153),
#  ('mbappe', 153),
#  ('hkeyet tounsia', 153),
#  ('fille', 153),
#  ('kerem catay', 152),
#  ('clip officiel', 152),
#  ('maquillage', 152),
#  ('cukur dizisi oyuncuları', 151),
#  ('cukur son', 151),
#  ('yamac', 151),
#  ('yamac ve sena', 151),
#  ('perihan savaş', 151),
#  ('celebrity', 151),
#  ('david hallyday', 151),
#  ('bebe', 150),
#  ('roufiaat al jalssa', 150),
#  ('analyse', 150),
#  ('culture', 150),
#  ('du', 150),
#  ('media', 150),
#  ('argent', 149),
#  ('crash', 149),
#  ('depression', 149),
#  ('koffi olomide', 149),
#  ('cukur izle', 149),
#  ('sofiane', 149),
#  ('comment faire', 148),
#  ('comique', 148),
#  ('remix', 148),
#  ('turkey', 148),
#  ('politics', 148),
#  ('رمضان 2018', 148),
#  ('lama fache', 147),
#  ('films', 147),
#  ('basketball', 147),
#  ('drama', 147),
#  ('musculation', 146),
#  ('journee', 146),
#  ('game', 146),
#  ('radhika in funny character', 146),
#  ('venu aravind', 146),
#  ('vanirani', 146),
#  ('vani', 146),
#  ('vaani', 146),
#  ("radhika's dual role serial", 146),
#  ('ranimma veetu kuripu', 146),
#  ('radhika as lawyer in serial', 146),
#  ('radikaa', 146),
#  ('choses utiles', 146),
#  ('video drole', 146),
#  ('basket', 146),
#  ('apple', 145),
#  ('guillaume play', 145),
#  ('goals', 145),
#  ('avis', 145),
#  ('sentv', 145),
#  ('officiel', 145),
#  ('maison', 144),
#  ('iphone', 144),
#  ('camera cachee', 143),
#  ('vegan', 143),
#  ('werrason', 143),
#  ('asmr', 143),
#  ('hakim jemili', 143),
#  ('artisanat', 143),
#  ('fait-main', 143),
#  ('kaaris', 142),
#  ('youtubeur', 142),
#  ('official', 142),
#  ('agathe auproux', 142),
#  ('jeune', 141),
#  ('gaming', 141),
#  ('anime', 141),
#  ('rappeur', 141),
#  ('fitness', 140),
#  ('dizi', 140),
#  ('jean-luc lemoine', 140),
#  ('equipe de france', 139),
#  ('nadhaswaram', 139),
#  ('thirupictures', 139),
#  ('thirumurugan', 139),
#  ('thirutv', 139),
#  ('europe', 139),
#  ('slime', 139),
#  ('booska-p', 138),
#  ('action', 138),
#  ('matthieu delormeau', 138),
#  ('2m', 138),
#  ('marion seclin', 138),
#  ('fiction', 137),
#  ('paranormal', 137),
#  ('kuladheivam', 137),
#  ('kuladeivam sun tv serial', 137),
#  ('yann barthes', 137),
#  ('camille combal', 137),
#  ('facebook', 137),
#  ('marvel', 137),
#  ('topito', 137),
#  ('tricks', 136),
#  ('lezapping', 136),
#  ('prison', 136),
#  ('laura smet', 136),
#  ('meilleur', 135),
#  ('interviews', 135),
#  ('jordan', 135),
#  ('nrj', 135),
#  ('ramadan 2018', 135),
#  ('astuce', 134),
#  ('famous', 134),
#  ('haul', 134),
#  ('laura', 134),
#  ('watchmojo francais', 134),
#  ('real', 133),
#  ('تليفزيون', 133),
#  ('rupture', 132),
#  ('nekfeu', 131),
#  ('orelsan', 131),
#  ('ecologie', 131),
#  ('laeticia', 131),
#  ('ballon', 130),
#  ('booskap', 130),
#  ('stand-up', 130),
#  ('emotion', 130),
#  ('voyage', 129),
#  ('guillaume radio sur nrj', 129),
#  ('suarez', 129),
#  ('cbs', 129),
#  ('religion', 129),
#  ('kelly vedovelli', 129),
#  ('album', 129),
#  ('top10', 128),
#  ('florian', 128),
#  ('fifa', 128),
#  ('un gars une fille', 128),
#  ('makeup', 128),
#  ('alonzo', 128),
#  ('kabila', 128),
#  ('point', 127),
#  ('web', 127),
#  ('gilles verdez', 127),
#  ('poisson', 127),
#  ('mode', 127),
#  ('dispute', 126),
#  ('celeb', 126),
#  ('geraldine maillet', 126),
#  ('maman', 126),
#  ('liste', 126),
#  ('complet', 126),
#  ('programme', 125),
#  ('fait-maison', 125),
#  ('مسلسلات رمضان 2018', 125),
#  ('peur', 124),
#  ('secret', 124),
#  ('quotidien', 124),
#  ('micro', 124),
#  ('tom villa', 124),
#  ('valerie benaim', 124),
#  ('10', 124),
#  ('legrandjd', 124),
#  ('accident', 123),
#  ('enquete', 123),
#  ('c a vous', 123),
#  ('promo', 123),
#  ('temoignage', 123),
#  ('listes', 122),
#  ('wass freestyle', 122),
#  ('el tessia', 122),
#  ('la villa des coeurs brises 3', 122),
#  ('rani', 121),
#  ('congo', 121),
#  ('التاسعة', 121),
#  ('isabelle morini bosc', 121),
#  ('marrant', 121),
#  ('sp:st=soccer', 121),
#  ('savoir-faire', 121),
#  ('mdr', 120),
#  ('rts', 120),
#  ('iphone x', 119),
#  ('olympique de marseille', 119),
#  ('cukur', 119),
#  ('movie', 119),
#  ('watchmojo', 119),
#  ('رمضان', 119),
#  ('routine', 118),
#  ('skills', 118),
#  ('thomas', 118),
#  ('activites manuelles', 118),
#  ('stephen colbert', 117),
#  ('amelie neten', 117),
#  ('adams', 117),
#  ('universal', 117),
#  ('christmas', 117),
#  ('david', 117),
#  ('unboxing', 116),
#  ('barca', 116),
#  ('ferre gola', 116),
#  ('nourriture', 116),
#  ('france inter', 116),
#  ('zapping web', 116),
#  ('priyamanaval today episode', 116),
#  ('sch', 116),
#  ('foot freestyle', 116),
#  ('amazing', 115),
#  ('cukur dizisi', 115),
#  ('ca zap', 115),
#  ('zapping canal', 115),
#  ('france 5', 115),
#  ('keblack', 115),
#  ('les anges de la tele realite', 115),
#  ('gradur', 115),
#  ('أخبار المغرب', 114),
#  ('alexandra lamy', 114),
#  ('manga', 114),
#  ('jean dujardin', 114),
#  ('wadioubakh', 114),
#  ('panice', 114),
#  ('attessia tv', 114),
#  ('al tasi3a', 114),
#  ('championnat', 114),
#  ('maddy', 114),
#  ('lartiste', 113),
#  ('hip-hop', 113),
#  ('music video', 113),
#  ('colbert', 113),
#  ('maxime gueny', 113),
#  ('records', 113),
#  ('mon', 113),
#  ('program', 113),
#  ('healthy', 112),
#  ('russie', 112),
#  ('le moment de meurice', 112),
#  ('priyamanaval serial', 112),
#  ('piriyamanaval', 112),
#  ('பிரியமானவள்', 112),
#  ('priyamanaval episode', 112),
#  ('periyamanaval', 112),
#  ('tours', 112),
#  ('eva', 112),
#  ('seneweb', 112),
#  ('sarah', 112),
#  ('velo', 111),
#  ('manu', 111),
#  ('medias', 111),
#  ('usa', 111),
#  ('guillaume meurice', 111),
#  ('french rap', 111),
#  ('ps4', 111),
#  ('les 10', 111),
#  ('nouvelle', 111),
#  ('game highlights', 111),
#  ('brico sympa', 111),
#  ('ecole', 110),
#  ('webserie', 110),
#  ('cristiano ronaldo', 110),
#  ('vaani rani', 110),
#  ("radhika's new", 110),
#  ('do it yourself', 110),
#  ('combine', 110),
#  ('up', 110),
#  ('docteur nozman', 110),
#  ('song', 110),
#  ('norman', 110),
#  ('femme', 110),
#  ('travaux manuels', 110),
#  ('squeezie', 109),
#  ('crash test', 109),
#  ('cheval', 109),
#  ('lutte', 109),
#  ('lyrics', 109),
#  ('anne-elisabeth lemoine', 109),
#  ('loulou', 108),
#  ('high-tech', 108),
#  ('family', 108),
#  ('vegetarien', 107),
#  ('guillaume radio', 107),
#  ('margot', 107),
#  ('ligue des champions', 107),
#  ('parents', 107),
#  ('adrien', 107),
#  ('projets faciles', 107),
#  ('lma', 107),
#  ('cazap', 106),
#  ('patrick cohen', 106),
#  ('nbc', 106),
#  ('fifi', 106),
#  ('concert', 106),
#  ('conseils', 106),
#  ('faits', 105),
#  ('شاهد', 105),
#  ('bizarre', 105),
#  ('smartphone', 105),
#  ('dieudonne', 105),
#  ('مسلسل', 105),
#  ('google', 105),
#  ('internet', 105),
#  ('rodriguez', 105),
#  ('habilete', 105),
#  ('how to', 104),
#  ('guillaume nrj', 104),
#  ('maxime switek', 104),
#  ('singing', 104),
#  ('rapide', 104),
#  ('cherif', 104),
#  ('pierre lescure', 104),
#  ('zap tele', 103),
#  ('2016', 103),
#  ('nrj12', 103),
#  ('foot mercato', 103),
#  ('barbara', 103),
#  ('comedy central', 103),
#  ('sale', 103),
#  ('malick', 103),
#  ('alima', 103),
#  ('raissa', 103),
#  ('penda', 103),
#  ('fashion', 103),
#  ('sncf', 103),
#  ('replay les anges', 103),
#  ('video les anges 10', 103),
#  ('animal', 102),
#  ('choc', 102),
#  ('gamemixtreize', 102),
#  ('star wars', 102),
#  ('experience', 102),
#  ('theatre congolais', 102),
#  ('dr nozman', 102),
#  ('chouchou', 102),
#  ("c'est mon choix", 102),
#  ('sen tv', 102),
#  ('axel merryl', 102),
#  ('david et laura', 102),
#  ('carlito', 101),
#  ('alexandre', 101),
#  ('lifehacks', 101),
#  ('rdc', 101),
#  ('hanouna', 101),
#  ('nozman', 101),
#  ('chien', 101),
#  ('priyamanaval episode today', 101),
#  ('cavani', 101),
#  ('patisserie', 101),
#  ('emission de television', 101),
#  ('محمد السادس', 100),
#  ('vu', 100),
#  ('goal', 100),
#  ('pourquoi laeticia', 100),
#  ('shanna kress', 100),
#  ('onpc', 99),
#  ('sanekh', 99),
#  ('canalplus', 99),
#  ('talent', 99),
#  ('information', 99),
#  ('marion ruggieri', 99),
#  ('court metrage', 99),
#  ('nba highlights', 99),
#  ('feminisme', 99),
#  ('m6', 99),
#  ('friends trip 4', 99),
#  ('marwa loud', 99),
#  ('urbex', 98),
#  ('faits interessants', 98),
#  ('info mercato', 98),
#  ('react', 98),
#  ('priyamanaval today', 98),
#  ('daily show with trevor noah', 98),
#  ('the daily show episodes', 98),
#  ('senegaltv', 98),
#  ('kinshasa', 98),
#  ('annonce', 98),
#  ('kalash', 98),
#  ('divorce', 98),
#  ('studio bagel', 98),
#  ('snap', 98),
#  ('manon', 98),
#  ('rathika', 97),
#  ('info transfert', 97),
#  ('tibo inshape', 97),
#  ('the daily show', 97),
#  ('trevor noah', 97),
#  ('oook.sn', 97),
#  ('france2', 97),
#  ('streaming', 97),
#  ('grand laye', 97),
#  ('sp:vl=fr', 97),
#  ('maabo', 97),
#  ('claire', 97),
#  ('thiru tv', 96),
#  ('kulatheivam yesterday', 96),
#  ('nbc tv', 96),
#  ('omg', 96),
#  ('peche', 96),
#  ('debutant', 96),
#  ('easy', 96),
#  ('irl', 95),
#  ('tips', 95),
#  ('اليوم', 95),
#  ('japon', 95),
#  ('trash', 95),
#  ('reactions', 95),
#  ('tellement vrai', 95),
#  ('societe', 95),
#  ('drague', 94),
#  ('tech', 94),
#  ('kuladheivam new serial', 94),
#  ('kuladheivam new sun tv serial', 94),
#  ('kuladheivam nadhaswaram replacement', 94),
#  ('kuladheivam today', 94),
#  ('kulatheivam today', 94),
#  ('kuladheivam yesterday', 94),
#  ('les grosses tete ruquier', 94),
#  ('les grosses tetes podcast', 94),
#  ('les grosses tetes rtl', 94),
#  ('les grosses tetes replay', 94),
#  ('les grosses tetes live', 94),
#  ('les grosses tetes best of', 94),
#  ('des', 94),
#  ('seth', 94),
#  ('seriesenegal', 94),
#  ('theatresenegal', 94),
#  ('trottoir', 94),
#  ('lifeline', 94),
#  ('rmc', 94),
#  ('fantome', 93),
#  ('vegetalien', 93),
#  ('rugby', 93),
#  ('oklm', 93),
#  ('studio', 93),
#  ("les princes et les princesses de l'amour 5", 93),
#  ('serie tv', 93),
#  ('choopa', 93),
#  ('cyprien', 93),
#  ('محمد صلاح', 93),
#  ('idol', 93),
#  ('rohff', 93),
#  ('francaise', 92),
#  ('codfamilya', 92),
#  ('son', 92),
#  ('comedians', 92),
#  ('leuztv', 92),
#  ('walftv', 92),
#  ('lambji', 92),
#  ('youssoundour', 92),
#  ('walyseck', 92),
#  ('assanediouf', 92),
#  ('meredial', 92),
#  ('thiererek', 92),
#  ('podetmarichou', 92),
#  ('jiixijaaxa', 92),
#  ('choix2vies', 92),
#  ('france 3', 92),
#  ('bike', 91),
#  ('netflix', 91),
#  ('team', 91),
#  ('zidane', 91),
#  ('les grosses tetes invites', 91),
#  ('booska', 91),
#  ('jojol', 91),
#  ('ousmane', 91),
#  ('gelongal', 91),
#  ('julien', 90),
#  ('fails', 90),
#  ('clip rap francais', 90),
#  ('tonton sene', 90),
#  ('akramjunior', 90),
#  ('reservoir prod', 90),
#  ('conference', 90),
#  ('fut', 89),
#  ('gopro', 89),
#  ('yamaha', 89),
#  ('dessin', 89),
#  ('paris saint-germain', 89),
#  ('clips rap', 89),
#  ('meyers', 89),
#  ('camera', 89),
#  ('freestyle football', 89),
#  ('dieu', 89),
#  ('hiphop', 89),
#  ('nouvelles', 89),
#  ('ca se discute', 89),
#  ('cokain.fr', 89),
#  ('audio', 88),
#  ('تلفزة الواقع', 88),
#  ('africa', 88),
#  ('satire', 88),
#  ('freestyle soccer', 88),
#  ('chat', 88),
#  ('mlg', 88),
#  ('remy', 88),
#  ('angoisse', 88),
#  ('destin', 88),
#  ('toute une histoire', 88),
#  ('confessions intimes', 88),
#  ('lorenzo', 88),
#  ('defis', 87),
#  ('fruits', 87),
#  ('تلفزة القرب', 87),
#  ('rfm', 87),
#  ('gratuit', 87),
#  ('justice', 87),
#  ('pere', 87),
#  ('jb mpiana', 87),
#  ('ligue 1 conforama', 87),
#  ('abi', 87),
#  ('heritage', 87),
#  ('hante', 86),
#  ('sound', 86),
#  ('ca tourne mal', 86),
#  ('madrid', 86),
#  ('chouf tv youtube', 86),
#  ('secret story', 86),
#  ('chansons', 86),
#  ('cadeau', 86),
#  ('yayın', 86),
#  ('mcfly', 85),
#  ('tests', 85),
#  ('cyril', 85),
#  ('les grosses tetes equipe', 85),
#  ('neige', 85),
#  ('ملخص', 85),
#  ('presentation', 85),
#  ('entier', 85),
#  ('ski', 85),
#  ('heritage de johnny', 85),
#  ('مسلسلات رمضان', 85),
#  ('et', 84),
#  ('mystere', 84),
#  ('photo', 84),
#  ('deco', 84),
#  ('prophete', 84),
#  ('moise katumbi', 84),
#  ('mlg highlights', 84),
#  ('opinion', 84),
#  ('nikola', 84),
#  ('finale', 84),
#  ('wolof', 84),
#  ('cellule', 84),
#  ('division', 84),
#  ('plays', 83),
#  ('armenia tv', 83),
#  ('lebron james', 83),
#  ('congolais', 83),
#  ('tournee', 83),
#  ('comedy central politics', 83),
#  ('the late show', 83),
#  ('late show', 83),
#  ('monologue', 83),
#  ('reinformation', 83),
#  ('highlight', 83),
#  ('festival', 83),
#  ('journal', 83),
#  ('malaise', 83),
#  ('celebrite', 83),
#  ('paroles', 83),
#  ('thomas les marseillais', 83),
#  ('chouf tv', 82),
#  ('voile', 82),
#  ('ugo', 82),
#  ('deces', 82),
#  ('aloula', 82),
#  ('felix tshisekedi', 82),
#  ('azhagu tamil serial', 82),
#  ('dab', 81),
#  ('mcfly et carlito', 81),
#  ('musulman', 81),
#  ('خبر', 81),
#  ('telecommande', 81),
#  ('ibratv', 81),
#  ('parody', 81),
#  ('technologie', 81),
#  ('avengers', 81),
#  ('decoration', 81),
#  ('relaxation', 81),
#  ('ambroise carminati', 80),
#  ('calvez', 80),
#  ('عاجل', 80),
#  ('stand', 80),
#  ('family friendly', 80),
#  ('tournage', 80),
#  ('hommage', 80),
#  ('wheeling', 80),
#  ('f2', 80),
#  ('telerealite', 80),
#  ('arame', 80),
#  ('combat', 80),
#  ('jade hallyday', 80),
#  ('binta', 80),
#  ('jules dousset', 79),
#  ('poisson fecond', 79),
#  ('entrainement', 79),
#  ('pranque', 79),
#  ('trap', 79),
#  ('comedy central comedians', 79),
#  ('uoif', 79),
#  ('dikoon', 79),
#  ('interview sam zirah', 79),
#  ('itw', 79),
#  ('poutine', 79),
#  ('rue', 79),
#  ('el', 79),
#  ('sam zirah en toute intimite', 79),
#  ('scandale', 79),
#  ('club', 79),
#  ('energie', 78),
#  ('արմենիա թի-վի', 78),
#  ('panarmenian tv', 78),
#  ('strategie', 78),
#  ('cours', 78),
#  ('bitcoin', 78),
#  ('tombe', 78),
#  ('en direct', 78),
#  ('nrj 12', 78),
#  ('l1', 78),
#  ('rachid', 78),
#  ('suntv serial', 78),
#  ('horreur', 77),
#  ('dessin anime', 77),
#  ('khundar', 77),
#  ('curiosites', 77),
#  ('zi', 77),
#  ('useful things', 77),
#  ('diy projects', 77),
#  ('champions', 77),
#  ('ca zap !', 77),
#  ('james corden', 77),
#  ('hd izle', 77),
#  ('gateau', 77),
#  ('exclusif', 77),
#  ('koreusity', 77),
#  ('nantes', 77),
#  ('social', 77),
#  ('militaire', 77),
#  ("ca commence aujourd'hui", 77),
#  ('jean', 77),
#  ('sun tv serials', 77),
#  ('vtt', 76),
#  ('mehdi ortelsberg', 76),
#  ('bastien ughetto', 76),
#  ('marine le pen', 76),
#  ('centre', 76),
#  ('late night talk show hosts', 76),
#  ('imam', 76),
#  ('investigation', 76),
#  ('the', 76),
#  ('gulli', 76),
#  ('homme', 76),
#  ('crazy', 76),
#  ('idees', 76),
#  ('bmx', 75),
#  ('cocovoit', 75),
#  ('crafts', 75),
#  ('verino', 75),
#  ('premium', 75),
#  ('comedy videos', 75),
#  ('funny clips', 75),
#  ('host', 75),
#  ('hornet la frappe', 75),
#  ('sadek', 75),
#  ('papa', 75),
#  ('pleure', 75),
#  ('cross', 75),
#  ('geek', 75),
#  ('thekairi78', 75),
#  ('ahmed', 75),
#  ('batflunch', 75),
#  ('romeo elvis', 75),
#  ('pourquoi laura', 75),
#  ('covoiturage', 74),
#  ('andrea vistoli', 74),
#  ('videos droles', 74),
#  ('zaptele', 74),
#  ('motivation', 74),
#  ('aventure', 74),
#  ('trucos de belliza', 74),
#  ('روتيني اليومي', 74),
#  ('syrie', 74),
#  ('miss france', 74),
#  ('vodk', 74),
#  ('juliette tresanini', 74),
#  ('pc', 74),
#  ('rallye', 74),
#  ('kpop', 74),
#  ('chaine', 74),
#  ('resume ligue 1 conforama', 74),
#  ('nathalie baye', 74),
#  ('soprano', 74),
#  ('\u202adavid hallyday\u202c', 74),
#  ('la fouine', 73),
#  ('bizbiz', 73),
#  ('naza', 73),
#  ('booskap91', 73),
#  ('alex', 73),
#  ('belgique', 73),
#  ('naps', 73),
#  ('gouvernement', 73),
#  ('idees creatives', 73),
#  ('troll', 73),
#  ('tristan', 73),
#  ('lookbook', 73),
#  ('survie', 73),
#  ('namel', 73),
#  ('\u202alaura smet\u202c', 73),
#  ('zap-tele', 72),
#  ('zappings', 72),
#  ('شوف تيفي', 72),
#  ('world cup', 72),
#  ('recommandations', 72),
#  ('corden', 72),
#  ...]

# %% [markdown]
# ##### Top 50 des tags

# %%
top_tags = []
for x, y in dico_tags_sorted[1:51]:
    top_tags.append(x)
top_tags
# Out:
# ['humour',
#  'football',
#  '2018',
#  'france',
#  'video',
#  'rap',
#  'drole',
#  'tv',
#  'francais',
#  'serie',
#  'paris',
#  'live',
#  'divertissement',
#  'freestyle',
#  'musique',
#  'foot',
#  '2017',
#  'interview',
#  'funny',
#  'senegal',
#  'sketch',
#  'film',
#  'music',
#  'psg',
#  'comedy',
#  'sport',
#  'fr',
#  'maroc',
#  'amour',
#  'johnny hallyday',
#  'top 10',
#  'television',
#  'vlog',
#  'politique',
#  'tuto',
#  'youtube',
#  'news',
#  'replay',
#  'comedie',
#  'highlights',
#  'neymar',
#  'rire',
#  'clip',
#  'theatre',
#  'cinema',
#  'top',
#  'fun',
#  'prank',
#  'zap',
#  'tpmp']

# %%
plt.figure(figsize=(16,26))

for x in range(len(top_tags)-1,-1,-1): 
    plt.barh(top_tags[x], df[df["tags"].str.contains(top_tags[x])].count())

plt.yticks(size=15)
plt.xlim(0,3000)
plt.title("Mot-clé (Top 50) / Nb d'occurences", fontsize=20)
plt.show()

# %%
plt.figure(figsize=(16,26))

for x in range(len(top_tags)-1,-1,-1): 
    plt.barh(top_tags[x], df["views"][df["tags"].str.contains(top_tags[x])])

plt.yticks(size=15)
plt.title("Mot-clé (Top 50) / Nb de vues", fontsize=20)
plt.show()

# %% [markdown]
# ### Taux d'engagement
# nb likes + nb commentaires / nb vues

# %%
df_engage = data_fr.copy()

# %%
df_engage = df_engage[~df_engage["category"].isnull()]

# %%
plt.figure(figsize=(18,8))

plt.bar(df_engage["category"], df_engage["engagement"], color="purple")
plt.xticks(rotation=70, size=15)
plt.yticks(size=15)

plt.title("Taux d'engagement / Catégories", size=35)

plt.show()

# %%
plt.figure(figsize=(18,8))
sns.distplot(df_engage["engagement"])
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.jointplot(data=df_engage, x="engagement", y="views")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.boxplot(data=df_engage, x="category", y="engagement")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(18,4))
sns.stripplot(data=df_engage, x="category", y="views")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,26))

for x in range(len(top_tags)-1,-1,-1): 
    plt.barh(top_tags[x], df_engage["engagement"][df_engage["tags"].str.contains(top_tags[x])])

plt.yticks(size=15)
plt.title("Mot-clé (Top 50) / Taux d'engagement", fontsize=20)
plt.show()

# %% [markdown]
# ### Graphs par durée

# %% [markdown]
# ### Brouillon
